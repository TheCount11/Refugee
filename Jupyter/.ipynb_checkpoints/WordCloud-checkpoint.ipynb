# %%
# imports and data reading
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from collections import Counter
import re
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import geopandas as gp

#read data
df = pd.read_csv(Path.cwd().parents[0] / "CSV" / "Raw"/ "all_tweets.csv")
df.head()
# Out:
#         long        lat           post_guid  \
# 0   9.159337  45.461345  821687743382167552
# 1  12.545146  41.898417  821691034749009921
# 2  -8.621914  41.162142  821690229597868032
# 3  12.545146  41.898417  821690521940881409
# 4  -2.115866  53.073712  821693014267559936
#
#                                            post_body    post_publish_date  \
# 0  L’esercito silenzioso delle #donne #migranti h...  2017-01-18 11:56:38
# 1  .@lauraravetto: #Migranti, “Che dice Minniti s...  2017-01-18 12:09:43
# 2             #refugeecrisis https://t.co/JQoSFvMTbl  2017-01-18 12:06:31
# 3  .@lauraravetto : #Migranti, “Che dice Minniti ...  2017-01-18 12:07:41
# 4  ".@theresa_may: '"We can still have EU workers...  2017-01-18 12:17:35
#
#                     hashtags emoji
# 0           {migranti,donne}    {}
# 1                 {Migranti}    {}
# 2            {refugeecrisis}    {}
# 3                 {Migranti}    {}
# 4  {Brexit,PMQs,immigration}    {}

# %%
#clean data

def clean_emoji(x):
    if x == '{}':
        return ''
    else:
        return x[1:-1]

df['emoji'] = df['emoji'].apply(clean_emoji)
df['hashtags'] = df['hashtags'].apply(lambda x:x[1:-1])
df.head()
# Out:
#         long        lat           post_guid  \
# 0   9.159337  45.461345  821687743382167552
# 1  12.545146  41.898417  821691034749009921
# 2  -8.621914  41.162142  821690229597868032
# 3  12.545146  41.898417  821690521940881409
# 4  -2.115866  53.073712  821693014267559936
#
#                                            post_body    post_publish_date  \
# 0  L’esercito silenzioso delle #donne #migranti h...  2017-01-18 11:56:38
# 1  .@lauraravetto: #Migranti, “Che dice Minniti s...  2017-01-18 12:09:43
# 2             #refugeecrisis https://t.co/JQoSFvMTbl  2017-01-18 12:06:31
# 3  .@lauraravetto : #Migranti, “Che dice Minniti ...  2017-01-18 12:07:41
# 4  ".@theresa_may: '"We can still have EU workers...  2017-01-18 12:17:35
#
#                   hashtags emoji
# 0           migranti,donne
# 1                 Migranti
# 2            refugeecrisis
# 3                 Migranti
# 4  Brexit,PMQs,immigration

# %%
#change timestamps to datetime format

df['post_publish_date'] = pd.to_datetime(df['post_publish_date'])
df['post_publish_date']
# Out:
# 0        2017-01-18 11:56:38
# 1        2017-01-18 12:09:43
# 2        2017-01-18 12:06:31
# 3        2017-01-18 12:07:41
# 4        2017-01-18 12:17:35
#                  ...
# 168248   2017-01-18 11:05:00
# 168249   2017-01-18 11:22:18
# 168250   2017-01-18 11:17:53
# 168251   2017-01-18 11:30:09
# 168252   2017-01-18 11:47:23
# Name: post_publish_date, Length: 168253, dtype: datetime64[ns]

# %%
#count the most common hashtags

results = Counter()
df['hashtags'].str.lower().str.split(',').apply(results.update)
print(results.most_common(30))
# Out:
# [('refugees', 16456), ('migranti', 14233), ('migrants', 12282), ('refugeeswelcome', 11789), ('muslimban', 10789), ('migration', 8852), ('immigration', 7454), ('refugee', 4562), ('refugiados', 3756), ('immigrazione', 3082), ('flüchtlinge', 3050), ('worldrefugeeday', 3018), ('withrefugees', 2845), ('eu', 2721), ('refugeecrisis', 2656), ('trump', 2349), ('asylum', 2179), ('migranten', 2149), ('hostileenvironment', 2046), ('brexit', 2045), ('immigrati', 2040), ('trndnl', 2015), ('migrant', 1901), ('immigrants', 1793), ('réfugiés', 1731), ('refugeesgr', 1707), ('vluchtelingen', 1672), ('greece', 1526), ('lesbos', 1512), ('rapefugees', 1499)]

# %%
len(results)
# Out:
# 68216

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
print(stopwords.fileids())
# Out:
# ['arabic', 'azerbaijani', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']
# [nltk_data] Downloading package stopwords to /home/sagnik/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#finding co-occuring hashtags with "migranti"

hashtags = df['hashtags'].tolist()
pattern = re.compile(r'(.*),(rapefugees)',re.IGNORECASE)
newlist = list(filter(pattern.match, hashtags))  
print(newlist[:10])
# Out:
# ['refugeesnotwelcome,rapefugeesnotwelcome', 'gropejihad,rapefugees', 'Keulen,rapefugees', 'Krimigranten,Rapefugees,Maghreb,Bankrotterklärung,Identitäten,Staat', 'Krimigranten,Rapefugees,Maghreb,Fallschirme,Kanonenboot', 'Medien,Rapefugees,Attentäter,Islamist,regional,Einzeltäter,psychisch,Flüchtling,friedlich', 'Krimigranten,Rapefugees,LINKE,Grünen,KazimAkboga,Merkel', 'Krimigranten,Illegale,Migranten,Rapefugees,Flüchtlinge,Islamisten', 'Krimigranten,Rapefugees,Grapscher,Flüchtlinge,Checklist,Islamisten,Invasoren', 'Krimigranten,Rapefugees,Migranten,Kontrolle,Asylrecht,Millionen']

# %%
#making the hashtags lowercase and separating them

foo = []
for item in newlist:
    foo.append(item.lower().split(','))
      
flat_list = [item for sublist in foo for item in sublist]
print(flat_list[:10])
# Out:
# ['refugeesnotwelcome', 'rapefugeesnotwelcome', 'gropejihad', 'rapefugees', 'keulen', 'rapefugees', 'krimigranten', 'rapefugees', 'maghreb', 'bankrotterklärung']

# %%
#turn into pandas dataframe for generating wordcloud

cloud = pd.DataFrame(flat_list,columns=['Co-occuring'])
cloud =cloud[cloud["Co-occuring"] != "rapefugees"]
cloud.head()
# Out:
#             Co-occuring
# 0    refugeesnotwelcome
# 1  rapefugeesnotwelcome
# 2            gropejihad
# 4                keulen
# 6          krimigranten

# %%
text = " ".join(review for review in cloud['Co-occuring'].astype(str))
print ("There are {} hashtags in the combination with #rapefugees in the dataset".format(len(text)))
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white", width=800, height=400).generate(text)
# Out:
# There are 66425 hashtags in the combination with #rapefugees in the dataset

# %%
#show wordcloud

plt.axis("off")
plt.figure(figsize=(40,20))
plt.tight_layout(pad=0)
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()

# %%
wordcloud = wordcloud.to_file('vluchtelingen.png')

# %%
df['post_body']
# Out:
# 0         L’esercito silenzioso delle #donne #migranti h...
# 1         .@lauraravetto: #Migranti, “Che dice Minniti s...
# 2                    #refugeecrisis https://t.co/JQoSFvMTbl
# 3         .@lauraravetto : #Migranti, “Che dice Minniti ...
# 4         ".@theresa_may: '"We can still have EU workers...
#                                 ...
# 168248    ". @JunckerEU  '"We want to get rid of this id...
# 168249    Malts should not be allowed to deal with #migr...
# 168250    #RussianDissident Artist Will Seek #Asylum in ...
# 168251    Just caught this sight out of my bedroom windo...
# 168252    "Innovators thrive '"when cultures collide and...
# Name: post_body, Length: 168253, dtype: object
